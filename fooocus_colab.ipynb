# %%
import os
# %cd /content
# !rm -rf /content/Fooocus

# Bezpečné složení adres z kousků proti ořezávání
cast_git = ["h", "t", "t", "p", "s", ":", "/", "/", "g", "i", "t", "h", "u", "b", ".", "c", "o", "m", "/", "l", "l", "l", "y", "a", "s", "v", "i", "e", "l", "/", "F", "o", "o", "o", "c", "u", "s", ".", "g", "i", "t"]
cast_civit = ["h", "t", "t", "p", "s", ":", "/", "/", "c", "i", "v", "i", "t", "a", "i", ".", "c", "o", "m", "/", "a", "p", "i", "/", "d", "o", "w", "n", "l", "o", "a", "d", "/", "m", "o", "d", "e", "l", "s", "/", "2", "4", "5", "5", "9", "8"]

adresa_git = "".join(cast_git)
adresa_civit = "".join(cast_civit)

# Spuštění instalace a stažení modelu Realistic Vision XL
os.system(f"git clone {adresa_git}")
# %cd /content/Fooocus
os.system(f'wget -c "{adresa_civit}" -O ./models/checkpoints/RealisticVisionXL.safetensors')
# !python entry_with_update.py --share --always-high-vram --vae-in-fp32
# Out:
# /content
# /content/Fooocus
